# %%
import pandas as pd
import numpy as np 
import seaborn as sns # mejora o complemeta el matploit 
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

sns.lineplot(x=x, y=y) # el sns esta basada en marplotlib 
plt.title("Grafico de Lineas")
plt.show()

# %%
df = pd.DataFrame({
    'categoria': ["A","B","C"],
    "valores": [10, 20, 30]
    
})

sns.barplot
